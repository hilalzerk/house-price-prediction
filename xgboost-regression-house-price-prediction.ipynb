# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/competitions/house-prices-advanced-regression-techniques/sample_submission.csv
# /kaggle/input/competitions/house-prices-advanced-regression-techniques/data_description.txt
# /kaggle/input/competitions/house-prices-advanced-regression-techniques/train.csv
# /kaggle/input/competitions/house-prices-advanced-regression-techniques/test.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 500)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# File paths
DATA_PATH = "/kaggle/input/competitions/house-prices-advanced-regression-techniques/"

# Load data
train = pd.read_csv(DATA_PATH + "train.csv")
test  = pd.read_csv(DATA_PATH + "test.csv")

# %%
train.shape
# Out:
# (1460, 81)

# %%
test.shape
# Out:
# (1459, 80)

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0   1          60       RL        65.00     8450   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story            7            5       2003          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace      196.00        Gd        TA      PConc       Gd       TA           No          GLQ         706          Unf           0        150          856    GasA        Ex          Y      SBrkr       856       854             0
# ...

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape LandContour Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# ...

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS (EDA)

# %%
train['SalePrice'].describe()
# Out:
# count     1460.00
# mean    180921.20
# std      79442.50
# min      34900.00
# 25%     129975.00
# 50%     163000.00
# 75%     214000.00
# max     755000.00
# Name: SalePrice, dtype: float64

# %%
# SalePrice - Original Distribution
fig, ax = plt.subplots()
ax.hist(train['SalePrice'], bins=50)
ax.set_title('SalePrice - Original Distribution')
ax.set_xlabel('SalePrice')
ax.set_ylabel('Count')
plt.show()

# %%
# SalePrice - Log Transformed
fig, ax = plt.subplots(figsize=(10, 5))
ax.hist(np.log1p(train['SalePrice']), bins=50)
ax.set_title('SalePrice - Log Transformed Distribution')
ax.set_xlabel('Log(SalePrice)')
ax.set_ylabel('Count')
plt.show()

# %%
# Missing values
train.isnull().sum()[train.isnull().sum() > 0].sort_values(ascending=False)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
# Numerical and categorical columns
numerical_cols   = train.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_cols = train.select_dtypes(include=['object']).columns.tolist()

len(numerical_cols), len(categorical_cols)
# Out:
# (38, 43)

# %%
# Correlation with SalePrice
corr = train[numerical_cols].corr()['SalePrice'].sort_values(ascending=False)
corr
# Out:
# SalePrice        1.00
# OverallQual      0.79
# GrLivArea        0.71
# GarageCars       0.64
# GarageArea       0.62
# TotalBsmtSF      0.61
# 1stFlrSF         0.61
# FullBath         0.56
# TotRmsAbvGrd     0.53
# YearBuilt        0.52
# YearRemodAdd     0.51
# GarageYrBlt      0.49
# MasVnrArea       0.48
# Fireplaces       0.47
# BsmtFinSF1       0.39
# LotFrontage      0.35
# WoodDeckSF       0.32
# 2ndFlrSF         0.32
# OpenPorchSF      0.32
# HalfBath         0.28
# LotArea          0.26
# BsmtFullBath     0.23
# BsmtUnfSF        0.21
# BedroomAbvGr     0.17
# ScreenPorch      0.11
# PoolArea         0.09
# MoSold           0.05
# 3SsnPorch        0.04
# BsmtFinSF2      -0.01
# BsmtHalfBath    -0.02
# MiscVal         -0.02
# Id              -0.02
# LowQualFinSF    -0.03
# YrSold          -0.03
# OverallCond     -0.08
# MSSubClass      -0.08
# EnclosedPorch   -0.13
# KitchenAbvGr    -0.14
# Name: SalePrice, dtype: float64

# %%
# Top 10 correlations
fig, ax = plt.subplots(figsize=(10, 6))
corr.drop('SalePrice').head(10).plot(kind='bar', ax=ax)
ax.set_title('Top 10 Features Correlated with SalePrice')
ax.set_ylabel('Correlation')
plt.xticks(rotation=45)
plt.show()

# %%
# Missing value strategy
# PoolQC, MiscFeature, Alley, Fence, FireplaceQu → "None" (feature doesn't exist)
# GarageType, GarageFinish, GarageQual, GarageCond → "None"
# BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2 → "None"
# MasVnrType → "None"
# LotFrontage → median by Neighborhood
# GarageYrBlt, MasVnrArea, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF → 0
# Electrical → mode

# Combine train and test for consistent cleaning
all_data = pd.concat([train.drop('SalePrice', axis=1), test], axis=0).reset_index(drop=True)
all_data.shape
# Out:
# (2919, 80)

# %%
# Fill missing values

# None → feature doesn't exist
none_cols = ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu',
             'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
             'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
             'MasVnrType']

for col in none_cols:
    all_data[col] = all_data[col].fillna('None')

# 0 → numerical feature doesn't exist
zero_cols = ['GarageYrBlt', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
             'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath',
             'GarageCars', 'GarageArea']

for col in zero_cols:
    all_data[col] = all_data[col].fillna(0)

# LotFrontage → median by Neighborhood
all_data['LotFrontage'] = all_data.groupby('Neighborhood')['LotFrontage'].transform(
    lambda x: x.fillna(x.median()))

# Electrical → mode
all_data['Electrical'] = all_data['Electrical'].fillna(all_data['Electrical'].mode()[0])

# MSZoning, Utilities, Exterior1st, Exterior2nd, KitchenQual, Functional, SaleType → mode
mode_cols = ['MSZoning', 'Utilities', 'Exterior1st', 'Exterior2nd',
             'KitchenQual', 'Functional', 'SaleType']

for col in mode_cols:
    all_data[col] = all_data[col].fillna(all_data[col].mode()[0])

# Check remaining missing values
all_data.isnull().sum()[all_data.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## Feature Engineering

# %%
# Total square footage
all_data['TotalSF'] = all_data['TotalBsmtSF'] + all_data['1stFlrSF'] + all_data['2ndFlrSF']

# Total bathrooms
all_data['TotalBath'] = (all_data['FullBath'] + all_data['BsmtFullBath'] +
                         0.5 * all_data['HalfBath'] + 0.5 * all_data['BsmtHalfBath'])

# House age
all_data['HouseAge'] = all_data['YrSold'] - all_data['YearBuilt']

# Remodel age
all_data['RemodelAge'] = all_data['YrSold'] - all_data['YearRemodAdd']

# Has pool, garage, basement, fireplace
all_data['HasPool']     = (all_data['PoolArea'] > 0).astype(int)
all_data['HasGarage']   = (all_data['GarageArea'] > 0).astype(int)
all_data['HasBasement'] = (all_data['TotalBsmtSF'] > 0).astype(int)
all_data['HasFireplace'] = (all_data['Fireplaces'] > 0).astype(int)

print(f"New features added. Shape: {all_data.shape}")
# Out:
# New features added. Shape: (2919, 88)

# %%
# Label Encoding for categorical columns
from sklearn.preprocessing import LabelEncoder

categorical_cols = all_data.select_dtypes(include=['object']).columns.tolist()

le = LabelEncoder()
for col in categorical_cols:
    all_data[col] = le.fit_transform(all_data[col].astype(str))

print(f"Categorical columns encoded: {len(categorical_cols)}")
all_data.shape
# Out:
# Categorical columns encoded: 43
# (2919, 88)

# %%
# Split back to train and test
X_train = all_data[:len(train)]
X_test  = all_data[len(train):]

# Log transform target variable
y_train = np.log1p(train['SalePrice'])

print(f"X_train : {X_train.shape}")
print(f"X_test  : {X_test.shape}")
print(f"y_train : {y_train.shape}")
# Out:
# X_train : (1460, 88)
# X_test  : (1459, 88)
# y_train : (1460,)

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score

# XGBoost model
xgb_model = XGBRegressor(
    n_estimators=1000,
    learning_rate=0.05,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    verbosity=0
)

# Cross validation
cv_scores = cross_val_score(
    xgb_model, X_train, y_train,
    cv=5,
    scoring='neg_mean_squared_error'
)

cv_rmse = np.sqrt(-cv_scores.mean())
print(f"5-Fold CV RMSE: {cv_rmse:.4f}")
# Out:
# 5-Fold CV RMSE: 0.1240

# %%
# Train model on full training data
xgb_model.fit(X_train, y_train)

# Predict on test set
predictions = np.expm1(xgb_model.predict(X_test))
# expm1 → log1p'nin tersi, log fiyatı gerçek fiyata çevirir

# Create submission file
submission = pd.DataFrame({
    'Id'       : test['Id'],
    'SalePrice': predictions
})

submission.to_csv('/kaggle/working/submission.csv', index=False)
submission.head()
# Out:
#      Id  SalePrice
# 0  1461  127340.20
# 1  1462  163679.33
# 2  1463  184162.11
# 3  1464  193685.09
# 4  1465  179795.98
